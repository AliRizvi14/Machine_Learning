# %% [markdown]
# <a href="https://colab.research.google.com/github/AliRizvi14/Machine_Learning/blob/main/Linear_multivariable_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('https://raw.githubusercontent.com/codebasics/py/master/ML/2_linear_reg_multivariate/Exercise/hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
pip install word2number
# Out:
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=62dcd75c4228a325502a533c611baac3bbd34c64d740393e4306d1801c8e2b15
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
# Successfully built word2number
# ...

# %%
from word2number import w2n

# %%
df.experience = df.experience.fillna("zero")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
import math
avg=math.floor(df['test_score(out of 10)'].mean())
avg
# Out:
# 7

# %%
df['test_score(out of 10)']=df['test_score(out of 10)'].fillna(avg)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
x=df.iloc[:,0:3]
x
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 0           0                    8.0                           9
# 1           0                    8.0                           6
# 2           5                    6.0                           7
# 3           2                   10.0                          10
# 4           7                    9.0                           6
# 5           3                    7.0                          10
# 6          10                    7.0                           7
# 7          11                    7.0                           8

# %%
y=df.iloc[:,3]
y
# Out:
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary($), dtype: int64

# %%
df.columns
# Out:
# Index(['experience', 'test_score(out of 10)', 'interview_score(out of 10)',
#        'salary($)'],
#       dtype='object')

# %%
model=linear_model.LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([53713.86677124])

# %%
model.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([93747.79628651])
